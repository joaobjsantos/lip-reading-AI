# %%
# %load_ext tensorboard

# %%
# %pip install pydot
# %pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydot in c:\users\jbsantos\appdata\roaming\python\python311\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\jbsantos\appdata\roaming\python\python311\site-packages (from pydot) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: graphviz in c:\users\jbsantos\appdata\roaming\python\python311\site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
import sys

from sympy import false

sys.path.append("..")

from nn_model import *


model = get_cnn_lstm_model()
keras.utils.plot_model(model,
    to_file='model.png',
    show_shapes=False,
    show_dtype=False,
    show_layer_names=False,
    rankdir='TB',
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
    show_trainable=False)
